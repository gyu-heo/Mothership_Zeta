# %%
# widen jupyter notebook window
from IPython.display import display, HTML
display(HTML("<style>.container {width:95% !important; }</style>"))
# Out:
# <style>.container {width:95% !important; }</style>

# %%
from pathlib import Path
import os
import sys
import numpy as np

import pickle
import logging
import natsort
from scipy.io import loadmat

# %%
dir_github = Path(r'/n/data1/hms/neurobio/sabatini/gyu/github_clone')
dir_mothership = Path(r'/n/data1/hms/neurobio/sabatini/gyu/github_clone/Mothership_Zeta/MZ')
dir_tracking = Path(r'/n/data1/hms/neurobio/sabatini/gyu/github_clone/Mothership_Zeta/MZ/tracking')

sys.path.append(dir_github)
sys.path.append(dir_mothership)
sys.path.append(dir_tracking)

# %%
pwd
# Out:
# '/n/data1/hms/neurobio/sabatini/gyu/github_clone'

# %%
# %load_ext autoreload
# %autoreload 2
from Mothership_Zeta.MZ.tracking.ROICaT import ROICaT_util
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load ROICaT result

# %%
dir_s2p = Path(r"/n/data1/hms/neurobio/sabatini/gyu/analysis/suite2p_output/mouse_g1/20221011/scanimage_data/exp/jobNum_0/suite2p/plane0").resolve()

# %%
tracked_UCIDs = ROICaT_util.ROICaT_loader(dir_s2p, 'exp', same_day = False, track_reference = 0)
# Out:
# WARNING:root:Session date 20221011
# WARNING:root:Cascade running
# WARNING:root:Loading ROICaT result...
# WARNING:root:/n/data1/hms/neurobio/sabatini/gyu/analysis/suite2p_output/mouse_g1/mouse_g1.ROICaT.results.pkl
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Loading day 20221011 UCIDs
# WARNING:root:Track_reference 0

# %% [markdown]
# # Offline scoring for each NMF factor dimension

# %%
for subpath in path.rglob('*'):

# %% [markdown]
# # Loading aligned behavior-logger

# %%
logger_name = loadmat("/n/data1/hms/neurobio/sabatini/gyu/github_clone/Mothership_Zeta/MZ/behavior/logger_align/expParams.mat")

# %%
logger_name
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Oct 13 19:09:56 2022',
#  '__version__': '1.0',
#  '__globals__': [],
#  'expParams': array([[(array([[30]], dtype=uint8), array([[108000]], dtype=int32), array([[20]], dtype=uint8), array([[4]], dtype=uint8), array([[0.066]]), array([[1.7]]), array([[-1.7,  1.7]]), array([[ 1000, 18000]], dtype=uint16), array([[3.1]]), array([[4]], dtype=uint8), array([[231]], dtype=uint8), array(['D:\\RH_local\\data\\BMI_cage_1511_3\\mouse_1\\20221013\\analysis_data'],
#                dtype='<U63'), array([[1800]], dtype=uint16), array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([[3]], dtype=uint8), array([[1]], dtype=uint8), array([[0.5]]), array([[64]], dtype=uint8), array([[0]], dtype=uint8), array([[0.2]]), array([[0.1]]), array([[60]], dtype=uint8), array(['hash = sum(sum(image,1).^2)'], dtype='<U27'), array([[(array([[array(['counter_frameNum'], dtype='<U16'),
# ...

# %%
logger_aligned = loadmat("/n/data1/hms/neurobio/sabatini/gyu/analysis/BWAIN_output/round_7_experiments/mouse_g1/20221013/logger_aligned.mat")
logger_alignment_vectors = loadmat("/n/data1/hms/neurobio/sabatini/gyu/analysis/BWAIN_output/round_7_experiments/mouse_g1/20221013/logger_alignment_vectors.mat")
logger_valsROIs_aligned = loadmat("/n/data1/hms/neurobio/sabatini/gyu/analysis/BWAIN_output/round_7_experiments/mouse_g1/20221013/logger_valsROIs_aligned.mat")

# %%
logger_aligned
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Nov 11 18:33:38 2022',
#  '__version__': '1.0',
#  '__globals__': [],
#  'logger_aligned': array([[(array([[ 2.,  0.,  0., ...,  1.,  0.,  1.],
#                 [ 3.,  0.,  0., ...,  1.,  0.,  1.],
#                 [ 4.,  0.,  0., ...,  1.,  0.,  1.],
#                 ...,
#                 [nan, nan, nan, ..., nan, nan, nan],
#                 [nan, nan, nan, ..., nan, nan, nan],
#                 [nan, nan, nan, ..., nan, nan, nan]]), array([[7.3880776e+05, 2.5135430e-01],
#                 [7.3880776e+05, 1.4224900e-02],
#                 [7.3880776e+05, 1.4326400e-02],
#                 ...,
#                 [          nan,           nan],
#                 [          nan,           nan],
#                 [          nan,           nan]]), array([[7.83574402e-01, 7.83574402e-01, 7.83574402e-01, 7.26705518e+03,
#                  2.26443529e+00],
# ...

# %%
len(logger_aligned['logger_aligned'][0][0][0][0])
# Out:
# 33

# %%
logger_alignment_vectors
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Nov 11 18:33:51 2022',
#  '__version__': '1.0',
#  '__globals__': [],
#  'logger_alignment_vectors': array([[(array([[nan],
#                 [ 1.],
#                 [ 2.],
#                 ...,
#                 [nan],
#                 [nan],
#                 [nan]]), array([[ 2.],
#                 [ 3.],
#                 [ 4.],
#                 ...,
#                 [nan],
#                 [nan],
#                 [nan]]), array([[5.83505446e+12]]), array([[1]], dtype=uint8), array([[6.01144721e+12],
#                 [6.09253795e+12],
#                 [6.13568846e+12],
#                 ...,
#                 [1.04879429e+13],
#                 [1.05033262e+13],
#                 [1.05684396e+13]]), array([[    15],
#                 [  2726],
#                 [  2727],
#                 ...,
#                 [107998],
#                 [107999],
# ...

# %%
logger_valsROIs_aligned
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Nov 11 18:33:39 2022',
#  '__version__': '1.0',
#  '__globals__': [],
#  'logger_valsROIs_aligned': array([[ 56999.859375  , 129948.6875    ,  13132.60351562, ...,
#            8258.0625    ,   8691.60449219,  12999.99902344],
#         [ 62300.68359375, 140981.21875   ,  12584.84179688, ...,
#            9435.41308594,   8744.73339844,  13629.14648438],
#         [ 51557.78125   , 125821.140625  ,  14495.80175781, ...,
#            8885.07519531,   8436.5       ,  11788.61425781],
#         ...,
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan]])}
